# %%
import pandas as pd

# %%
df1 = pd.DataFrame(data = [[1,2,'x'],[5,6,'y'],[9,10,'z']],columns = ['a','b','c'])
df2 = pd.DataFrame(data = [['x'],['y'],['z']],columns = ['f'])

# %%
df1.head()
# Out:
#    a   b  c
# 0  1   2  x
# 1  5   6  y
# 2  9  10  z

# %%
df1.head()
# Out:
#    a   b  c
# 0  1   2  x
# 1  5   6  y
# 2  9  10  z

# %% [markdown]
# pd - axis
